# %%
import geopandas as gpd
import numpy as np

# %%
def calc_bike_street_ratio(df_in):
    df = df_in.copy()
    df['BIKE_STREET_PER'] = np.round((df['SUM_LENGTH'] / df['LENGTH']) * 100 , 2)

    return df

# %%
def calc_ratio(df_in):
    df = df_in.copy()
    #replace entries with '...' with 0
    df['YES_IN_PER'] = df['YES_IN_PER'].replace('...', 0)
    #change type of 'YES_IN_PER' to float
    df['YES_IN_PER'] = df['YES_IN_PER'].astype(float)
    #fill na values with 0
    df['YES_IN_PER'] = df['YES_IN_PER'].fillna(0)
    df['DIV'] = (df['BIKE_STREET_PER'] / df['YES_IN_PER'])
    df['ADD'] = (df['BIKE_STREET_PER'] + df['YES_IN_PER'])
    df['SUB'] = (df['BIKE_STREET_PER'] - df['YES_IN_PER'])
    df['MUL'] = (df['BIKE_STREET_PER']/100) * (df['YES_IN_PER']/100)
    # PER DIFF subtract value A from value B, divide the result by the average of the two values, and then multiply by 100 to get a percentage
    df['PER_DIFF_Y'] = (df['YES_IN_PER'] - df['BIKE_STREET_PER']) / ((df['BIKE_STREET_PER'] + df['YES_IN_PER'])/2) * 100
    df['PER_DIFF_B'] = (df['BIKE_STREET_PER'] - df['YES_IN_PER']) / ((df['BIKE_STREET_PER'] + df['YES_IN_PER'])/2) * 100


    return df

# %%
master = gpd.read_file('../export/master/master_acc_bike_pop_street.geojson')

# %%
ratio = calc_bike_street_ratio(master)

# %%
res = calc_ratio(ratio)

# %%
res.sort_values(by=['PER_DIFF_Y'], ascending=True)
# Out:
#       BFSNR                                            GMDNAME  \
# 411     877  Niedermuhlern (Gemeinsame Urne, Standort: Wald...
# 1548   5203                                            Morcote
# 446     947                                        Zwieselberg
# 546    1121                                          Alberswil
# 724    2194                                          Ferpicloz
# ...     ...                                                ...
# 2117   6773                                        Beurnevésin
# 2119   6775                                             Bonfol
# 2121   6781                                             Coeuve
# 2127   6790                                          Fontenais
# 2130   6806                                       Vendlincourt
#
#      ELIGIBLE_VOTERS TOT_VOTES PART_PERCENT VALID_VOTES  YES   NO  YES_IN_PER  \
# 411              ...       ...          ...         ...  ...  ...        0.00
# 1548             414       191        46.14         187   61  126       32.62
# 446              241        75        31.12          75   47   28       62.67
# 546              467       160        34.26         160  101   59       63.13
# 724              181        72        39.78          72   43   29       59.72
# ...              ...       ...          ...         ...  ...  ...         ...
# 2117             122        34        27.87          34   22   12       64.71
# 2119             607       140        23.06         137  104   33       75.91
# 2121             572       146        25.52         145  119   26       82.07
# 2127            1256       372        29.62         369  312   57       84.55
# 2130             472       139        29.45         134   97   37       72.39
#
#       BZNR  ...         LENGTH  COUNT  BIKE_STREET_PER  \
# 411    246  ...   48777.067338  270.0            11.82
# 1548  2105  ...   24189.642439  169.0            17.07
# 446    247  ...   24541.340793  192.0            28.30
# 546    315  ...   35115.772438  349.0            23.31
# 724   1004  ...    7417.500034   69.0            21.55
# ...    ...  ...            ...    ...              ...
# 2117  2603  ...   32082.129448  183.0              NaN
# 2119  2603  ...   75292.589147  520.0              NaN
# 2121  2603  ...   64189.239988  342.0              NaN
# 2127  2603  ...  142469.688304  771.0              NaN
# 2130  2603  ...   53832.029439  360.0              NaN
#
#                                                geometry       DIV    ADD  \
# 411   POLYGON ((2603360.000 1190760.000, 2603472.000...       inf  11.82
# 1548  POLYGON ((2714790.000 1088853.000, 2714341.000...  0.523299  49.69
# 446   POLYGON ((2614729.000 1173109.000, 2614807.000...  0.451572  90.97
# 546   POLYGON ((2642744.000 1223317.000, 2643135.000...  0.369238  86.44
# 724   POLYGON ((2578148.000 1177080.000, 2578626.000...  0.360851  81.27
# ...                                                 ...       ...    ...
# 2117  POLYGON ((2576583.000 1258798.000, 2575940.000...       NaN    NaN
# 2119  POLYGON ((2576583.000 1258798.000, 2577154.000...       NaN    NaN
# 2121  POLYGON ((2574443.000 1253870.000, 2574300.000...       NaN    NaN
# 2127  POLYGON ((2569410.484 1246416.863, 2569387.599...       NaN    NaN
# 2130  POLYGON ((2580412.000 1257077.000, 2580367.000...       NaN    NaN
#
#         SUB       MUL  PER_DIFF_Y  PER_DIFF_B
# 411   11.82  0.000000 -200.000000  200.000000
# 1548 -15.55  0.055682   62.588046  -62.588046
# 446  -34.37  0.177356   75.563373  -75.563373
# 546  -39.82  0.147156   92.133272  -92.133272
# 724  -38.17  0.128697   93.933801  -93.933801
# ...     ...       ...         ...         ...
# 2117    NaN       NaN         NaN         NaN
# 2119    NaN       NaN         NaN         NaN
# 2121    NaN       NaN         NaN         NaN
# 2127    NaN       NaN         NaN         NaN
# 2130    NaN       NaN         NaN         NaN
#
# [2135 rows x 29 columns]
